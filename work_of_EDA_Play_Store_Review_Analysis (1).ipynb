# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import seaborn as sns
from matplotlib import rcParams

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path1='/content/drive/MyDrive/playstore eda/Play Store Data.csv'
df1=pd.read_csv(path1)

# %%
path_2='/content/drive/MyDrive/playstore eda/User Reviews.csv'
df2=pd.read_csv(path_2)

# %%
df1.head().T
# Out:
#                                                              0  \
# App             Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                        ART_AND_DESIGN
# Rating                                                     4.1
# Reviews                                                    159
# Size                                                       19M
# Installs                                               10,000+
# Type                                                      Free
# Price                                                        0
# Content Rating                                        Everyone
# Genres                                            Art & Design
# Last Updated                                   January 7, 2018
# Current Ver                                              1.0.0
# Android Ver                                       4.0.3 and up
#
#                                         1  \
# ...

# %%
df1.tail().T
# Out:
#                            10836                             10837  \
# App             Sya9a Maroc - FR  Fr. Mike Schmitz Audio Teachings
# Category                  FAMILY                            FAMILY
# Rating                       4.5                               5.0
# Reviews                       38                                 4
# Size                         53M                              3.6M
# Installs                  5,000+                              100+
# Type                        Free                              Free
# Price                          0                                 0
# Content Rating          Everyone                          Everyone
# Genres                 Education                         Education
# Last Updated       July 25, 2017                      July 6, 2018
# Current Ver                 1.48                               1.0
# Android Ver           4.1 and up                        4.1 and up
#
# ...

# %%
df1.shape
# Out:
# (10841, 13)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
median_value =df1['Rating'].median()
median_value
# Out:
# 4.3

# %%
mode_value= df1["Type"].mode()[0]
mode_value
# Out:
# 'Free'

# %%
df1['Rating'].fillna(median_value,inplace=True)

# %%
 df1['Type'].fillna(mode_value,inplace=True)

# %%
df1['Android Ver'].fillna(df1['Android Ver'].mode()[0],inplace=True)
df1['Current Ver'].fillna(df1['Current Ver'].mode()[0],inplace=True)
df1['Content Rating'].fillna(df1['Content Rating'].mode()[0],inplace = True)

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df1.describe()
# Out:
#              Rating
# count  10841.000000
# mean       4.207841
# std        0.500893
# min        1.000000
# 25%        4.100000
# 50%        4.300000
# 75%        4.500000
# max       19.000000

# %%
df1.boxplot('Rating');

# %%
df1[df1.Rating>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone       Everyone  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up  4.1 and up

# %%
df1.drop([10472],inplace=True)

# %%
df1[10470:10475]
# Out:
#                                            App         Category  Rating  \
# 10470                               Jazz Wi-Fi    COMMUNICATION     3.4
# 10471                         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
# 10473                  osmino Wi-Fi: free WiFi            TOOLS     4.2
# 10474                             Sat-Fi Voice    COMMUNICATION     3.4
#
#       Reviews    Size     Installs  Type     Price Content Rating  \
# 10470      49    4.0M      10,000+  Free         0       Everyone
# 10471    1042    404k     100,000+  Free         0       Everyone
# 10472    3.0M  1,000+         Free     0  Everyone       Everyone
# 10473  134203    4.1M  10,000,000+  Free         0       Everyone
# 10474      37     14M       1,000+  Free         0       Everyone
#
#                   Genres       Last Updated Current Ver   Android Ver
# ...

# %%
df1.boxplot();

# %%
df1.duplicated(subset=["App"]).sum()
# Out:
# 1181

# %%
df1[df1.duplicated(subset=["App"])]
# Out:
#                                       App       Category  Rating Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2   80805
# 236                                   Box       BUSINESS     4.2  159872
# 239                    Google My Business       BUSINESS     4.4   70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4   31614
# 261             join.me - Simple Meetings       BUSINESS     4.0    6989
# ...                                   ...            ...     ...     ...
# 10715                  FarmersOnly Dating         DATING     3.0    1145
# 10720  Firefox Focus: The privacy browser  COMMUNICATION     4.4   36981
# 10730                         FP Notebook        MEDICAL     4.5     410
# 10753      Slickdeals: Coupons & Shopping       SHOPPING     4.5   33599
# 10768                                AAFP        MEDICAL     3.8      63
#
#                      Size     Installs  Type Price Content Rating  \
# ...

# %%
df1.drop_duplicates(subset=['App'],keep='first',inplace=True) #delete rows accept the first duplicate one

# %%
df1.shape
# Out:
# (9659, 13)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          9659 non-null   float64
#  3   Reviews         9659 non-null   object
#  4   Size            9659 non-null   object
#  5   Installs        9659 non-null   object
#  6   Type            9659 non-null   object
#  7   Price           9659 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9659 non-null   object
#  12  Android Ver     9659 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %%
type('size')
# Out:
# str

# %%
type('Last Updated')
# Out:
# str

# %%
df1['Reviews']=df1['Reviews'].astype(int)

# %%
df1['Price']=df1['Price'].apply(lambda x: x.replace('$','') if '$' in str(x) else x)

df1['Price']=df1['Price'].astype(float)

# %%
df1['Installs']=df1['Installs'].apply(lambda x: x.replace('+','') if '+' in str(x) else x)
df1['Installs']=df1['Installs'].apply(lambda x: x.replace(',','') if ',' in str(x) else x)
df1['Installs']=df1['Installs'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10840 non-null  object
#  12  Android Ver     10840 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
df1['Type'].value_counts()
# Out:
# Free    10040
# Paid      800
# Name: Type, dtype: int64

# %%
df1['Price'].max() # max paid app on play store
# Out:
# 400.0

# %%
df1.hist();

# %%
df1.value_counts('Rating')
# Out:
# Rating
# 4.3    2550
# 4.4    1109
# 4.5    1038
# 4.2     952
# 4.6     823
# 4.1     708
# 4.0     568
# 4.7     499
# 3.9     386
# 3.8     303
# 5.0     274
# 3.7     239
# 4.8     234
# 3.6     174
# 3.5     163
# 3.4     128
# 3.3     102
# 4.9      87
# 3.0      83
# 3.1      69
# 3.2      64
# 2.9      45
# 2.8      42
# 2.7      25
# 2.6      25
# 2.5      21
# 2.3      20
# 2.4      19
# 1.0      16
# 2.2      14
# 1.9      13
# 2.0      12
# 2.1       8
# 1.8       8
# 1.7       8
# 1.6       4
# 1.5       3
# 1.4       3
# 1.2       1
# dtype: int64

# %%
df1.value_counts("Installs")
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           907
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# dtype: int64

# %%
sns.scatterplot(x="Category", y="Price",data=df1)

plt.xticks(rotation=90)
plt.figure(figsize=(30,9))
rcParams['figure.figsize'] = 30,9

# %%
plt.figure(figsize=(18,6))

ax = sns.countplot(x="Category",data=df1,palette="Paired")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
ax 
plt.title('Categorywise count of app',size = 18)
ax.grid(False)
sns.set_style('white')

# %%
#plot histogram from rating column
plt.figure(figsize=(13,8))
print(f"average rating for app is {round(df1['Rating'].mean(),5)}")

df1['Rating'].hist(color='b')
plt.title('Google play app rating distribution')
plt.ylabel('App count')
plt.xlabel('Rating out of 5')
plt.grid(False)
plt.show()
# Out:
# average rating for app is 4.20648

# %%
df1.sort_values('Rating',inplace=True)

# %%
df1.head(20)
# Out:
#                                                     App            Category  \
# 6319                   BJ Bridge Standard American 2018                GAME
# 7383                                     Thistletown CI        PRODUCTIVITY
# 10324                    FE Mechanical Engineering Prep              FAMILY
# 5151                                      Clarksburg AH             MEDICAL
# 7427                                     CJ DVD Rentals       COMMUNICATION
# 7806                                        CR Magazine            BUSINESS
# 8875                                     DT future1 cam               TOOLS
# 6490                                             MbH BM             MEDICAL
# 7926                               Tech CU Card Manager             FINANCE
# 10591  Lottery Ticket Checker - Florida Results & Lotto               TOOLS
# 7144                                      CB Mobile Biz             FINANCE
# ...

# %%
df2.shape
# Out:
# (64295, 5)

# %%
df3=pd.merge(df1,df2, on='App')
df3.head().T
# Out:
#                                                                      0  \
# App                     EliteSingles – Dating for Single Professionals
# Category                                                        DATING
# Rating                                                             2.5
# Reviews                                                           5377
# Size                                                               19M
# Installs                                                        500000
# Type                                                              Free
# Price                                                              0.0
# Content Rating                                              Mature 17+
# Genres                                                          Dating
# Last Updated                                             July 31, 2018
# Current Ver                                                      4.8.5
# ...

# %%
df3.info();
df3.tail().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122662 entries, 0 to 122661
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   App                     122662 non-null  object
#  1   Category                122662 non-null  object
#  2   Rating                  122662 non-null  float64
#  3   Reviews                 122662 non-null  int64
#  4   Size                    122662 non-null  object
#  5   Installs                122662 non-null  int64
#  6   Type                    122662 non-null  object
#  7   Price                   122662 non-null  float64
#  8   Content Rating          122662 non-null  object
#  9   Genres                  122662 non-null  object
#  10  Last Updated            122662 non-null  object
#  11  Current Ver             122662 non-null  object
#  12  Android Ver             122662 non-null  object
#  13  Translated_Review       72605 non-null   object
# ...

# %%
df3.shape
# Out:
# (122662, 17)

# %%
df3.describe()
# Out:
#               Rating       Reviews      Installs          Price  \
# count  122662.000000  1.226620e+05  1.226620e+05  122662.000000
# mean        4.322397  2.243249e+06  7.304089e+07       0.128265
# std         0.284720  6.324819e+06  1.896831e+08       1.563680
# min         2.500000  1.000000e+01  1.000000e+03       0.000000
# 25%         4.200000  2.752400e+04  1.000000e+06       0.000000
# 50%         4.400000  1.598720e+05  1.000000e+07       0.000000
# 75%         4.500000  1.500999e+06  1.000000e+08       0.000000
# max         4.900000  7.815831e+07  1.000000e+09      33.990000
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        72615.000000            72615.000000
# mean             0.157320                0.494162
# std              0.332652                0.240144
# min             -1.000000                0.000000
# 25%              0.000000                0.380000
# 50%              0.129167                0.509740
# ...

# %%
#Polarity is the output that lies between [-1,1], where -1 refers to negative sentiment and +1 refers to positive sentiment. 
# A good example would be the following: ‘I don’t think I’ll buy this item because my previous experience with a similar item wasn’t so good.’ That will have a negative polarity.
#Subjectivity is the output that lies within [0,1] and refers to personal opinions and judgments.
#‘I’m very happy with my new smartphone because it has the highest performance available on the market.’
